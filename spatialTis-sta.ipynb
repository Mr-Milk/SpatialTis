# %%
import numpy as np
import pandas as pd
import anndata as ad

import spatialtis.sta as st
import spatialtis.plotting as sp

# %%
# load data
data = ad.read_h5ad('tmp/test_adata.h5ad')
data
# Out:
# AnnData object with n_obs × n_vars = 152037 × 36
#     obs: 'Patient', 'Part', 'ROI', 'cell_shape', 'leiden'
#     var: 'Channels', 'Markers'
#     uns: 'leiden', 'leiden_colors', 'neighbors', 'pca'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'

# %%
st.cell_components(data, 'leiden', ['Patient','Part','ROI'], selected_type=["4","5","6","7"])
sp.cell_components(data, ['Patient'], percentage=False, size=(400,400), save_svg="tmp/bar.svg")
# Out:
# Finished!
#         Add to AnnData object
#         uns: 'cell_components'
#   <div class="bk-root" id="71d1f6f6-9740-4016-9eec-eab5fb70be68" data-root-id="1003"></div>

# %%
st.cell_density(data, 'leiden', ['Patient','Part','ROI'], (1000,1000), selected_type=["4","5","6","7"])
# Out:
# Finished!
#         Add to AnnData object
#         uns: 'cell_density'

# %%
sp.cell_density(data, ['Patient'], direction='horizontal', title="cell density")
# Out:
#   <div class="bk-root" id="2d9d41c7-67e6-4f16-8611-06cda15ac673" data-root-id="1349"></div>

# %% [raw]
# 0 - 1
# 0 - 100
#
# (100 - 0)/(100 - 0)

# %% [raw]
# ROI = data.obs[(data.obs['Patient'] == 'HPAP005')&
#               (data.obs['Part'] == 'Tail')&
#               (data.obs['ROI'] == 'ROI1')]
# sp.cell_map(ROI, 'leiden', save_html="cell_map.html")

# %% [raw]
# data.write('tmp/test_adata_pd.h5ad')

# %% [raw]
# data = ad.read_h5ad('tmp/test_adata_pd.h5ad')
# data

# %% [raw]
# sp.cell_components(data, ['Patient','Part'])
